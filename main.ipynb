# %%
import os
DEFAULT_FS = 16000
dst_dir = "/catclass/output"

os.system(("yt-dlp -f 'bestaudio' ytsearch1:'cat in heat' -P /catclass/temp/"))
# Out:
# [youtube:search] Extracting URL: ytsearch1:cat in heat
# [download] Downloading playlist: cat in heat
# [youtube:search] query "cat in heat": Downloading web client config
# [youtube:search] query "cat in heat" page 1: Downloading API JSON
# [youtube:search] Playlist cat in heat: Downloading 1 items of 1
# [download] Downloading item 1 of 1
# [youtube] Extracting URL: https://www.youtube.com/watch?v=tb24B2Y-51M
# [youtube] tb24B2Y-51M: Downloading webpage
# [youtube] tb24B2Y-51M: Downloading ios player API JSON
# [youtube] tb24B2Y-51M: Downloading android player API JSON
# [youtube] tb24B2Y-51M: Downloading m3u8 information
# [info] tb24B2Y-51M: Downloading 1 format(s): 251
# [download] /catclass/temp/Female cat in heat meowing ( mate calling ) [tb24B2Y-51M].webm has already been downloaded
# [download] 100% of  972.68KiB
# [download] Finished downloading playlist: cat in heat
# 0

# %%
from glob import glob
base_dir = '/catclass/temp'
train_folder = glob(base_dir)

train_path = []
print(train_folder)
for folder in train_folder:
    tmp = glob(folder + '/*')
    train_path += tmp
# Out:
# ['/catclass/temp']

# %%
findli = list(map(lambda x : x.split('[')[0],train_path))
delli = [0 for _ in range(len(train_path))]
for k in range(len(train_path)):
    if delli[k]!=1:
        templi = [i for i, j in enumerate(findli) if j == findli[k]]
        for p in templi:
            delli[p]=1
        delli[k]=0
for i in range(len(delli)):
    if delli[i]==1:
        print(train_path[i])
        os.system("rm '"+train_path[i]+"'")
# Out:
# /catclass/temp/emoji cat heat [k6YOJy4qIh0].webm
# /catclass/temp/uwu cat [Lbun010CtSY].webm
# /catclass/temp/stop emoji cat heat [sFw2j3aIdSU].webm
# /catclass/temp/stop emoji cat heat [NGsyEQI77pU].webm
# /catclass/temp/How to Help a Female Cat in Heat？ [IV4CE2bmk50].webm
# /catclass/temp/stop emoji cat heat [kAJH1sWpk98].webm
# /catclass/temp/Emojicat heat compilation🥵 [ZhYH7t8QYEs].webm
# /catclass/temp/stop emoji cat heat [Cn93TFagshM].webm
# /catclass/temp/stop emoji cat heat [pZa0G9dh3fk].webm
# /catclass/temp/How to calm a cat in heat [x4Sh1_ZquPM].webm
# /catclass/temp/stop emoji cat heat [VMAulWyEjsE].webm
# /catclass/temp/emoji cat heat~ [EAynqWipIrY].webm
# /catclass/temp/stop emoji cat heat [90dLJAWlfEg].webm
# /catclass/temp/emoji cat heat [PkyZwFZk4Fg].webm
# /catclass/temp/stop emoji cat heat [MhrgXfpsPjM].webm
# /catclass/temp/😺 Emoji Cat TikTok Heat 🥵 Emoji Cat TikTok Compilation Heat  😸 [-nIvFrfhxL0].webm
# ...

# %%
from glob import glob
base_dir = '/catclass/temp'
train_folder = glob(base_dir)

train_path = []
print(train_folder)
for folder in train_folder:
    tmp = glob(folder + '/*')
    train_path += tmp
# Out:
# []

# %%
print(train_path)
# Out:
# ['/catclass/temp/emoji cat heat❌ [S6qddz46Atk].webm', '/catclass/temp/Cat on Heat - Male Cat In Heat Goes Crazy [6t4yzyTXDQw].webm', '/catclass/temp/Acupressure for a cat in heat. How to deal with your cat in heat. [6nwhoESzAMU].webm', '/catclass/temp/My Male Cat in Heat ｜ Male Cat Heat sign & symptoms  ｜ Male Cat heat Sound ｜ Male Cat Calling Female [sXIuYrwsEQk].webm', '/catclass/temp/Th story of the two cats (WCUE heat) (DO NOT CLICK ON IF YOU HATE WCUE HEAT) [ferBPG4RNBA].webm', '/catclass/temp/SOUNDS to Make Your CAT COME to CUDDLE YOU 📣🐈 (Meows to ATTRACT Your CAT When They HIDE) [7evOGAmMc_Y].webm', '/catclass/temp/l Проду？❤ l #Gacha#Гача#Срача [Vx3gRn0L37w].webm', '/catclass/temp/Calming Videos for Cats - TV to Relax Your Cat and My Cat at Home ： The Bird Garden [_jqWwQNWsg4].webm', '/catclass/temp/Gacha heat with UwU Cat~~~~~ 🥵🥵🥵🥵🥵🥵🥵🥵 [fb9w6KiseVE].webm', '/catclass/temp/stop emoji cat heat!! [68Y_Y93dxgc].webm', '/catclass/temp/stop emoji cat heat!!!!! [EDUOwD19avY].webm', 
# ...

# %%
for i in range(len(train_path)):
    os.system(("ffmpeg -y -i '" + train_path[i] + "' -ar " + str(DEFAULT_FS) + " -- \"" + dst_dir + "/" + str(i) + ".wav\""))
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
base_dir = '/catclass/output'
train_folder = glob(base_dir)
train_path = []
for folder in train_folder:
    tmp = glob(folder + '/*')
    train_path += tmp
print(*train_path,sep='\n')
# Out:
# /catclass/output/196.wav
# /catclass/output/134.wav
# /catclass/output/292.wav
# /catclass/output/69.wav
# /catclass/output/9.wav
# /catclass/output/88.wav
# /catclass/output/23.wav
# /catclass/output/123.wav
# /catclass/output/388.wav
# /catclass/output/229.wav
# /catclass/output/260.wav
# /catclass/output/60.wav
# /catclass/output/150.wav
# /catclass/output/66.wav
# /catclass/output/2.wav
# /catclass/output/230.wav
# /catclass/output/181.wav
# /catclass/output/223.wav
# /catclass/output/160.wav
# /catclass/output/217.wav
# /catclass/output/322.wav
# /catclass/output/114.wav
# /catclass/output/177.wav
# /catclass/output/394.wav
# /catclass/output/51.wav
# /catclass/output/353.wav
# /catclass/output/337.wav
# /catclass/output/130.wav
# /catclass/output/149.wav
# /catclass/output/214.wav
# /catclass/output/48.wav
# /catclass/output/247.wav
# /catclass/output/30.wav
# /catclass/output/195.wav
# /catclass/output/72.wav
# /catclass/output/408.wav
# /catclass/output/357.wav
# ...

# %%
import os
import librosa

DEFAULT_FS = 16000
dst_dir = "/catclass/output1"
cur=387
cnt=0
#os.system(("ffmpeg -y -ss " + str(cnt*300) + " -t 300" + " -i '" + train_path[i] + "' -ar " + str(DEFAULT_FS) + " -- \"" + dst_dir + "/" + str(cur) + ".wav\""))
for i in range(len(train_path)):
    dur=librosa.get_duration(path=train_path[i])
    #print(librosa.get_duration(path=train_path[i]))
    #print(train_path[i])
    cnt=0
    for cnt in range(int(dur//300)):
        os.system(("ffmpeg -y -ss " + str(cnt*300) + " -t 300 " + "-i '" + train_path[i] + "' -ar " + str(DEFAULT_FS) + " -- \"" + dst_dir + "/" + str(cur) + ".wav\""))
        cur+=1
    os.system(("ffmpeg -y -ss " + str(cnt*300) + " -t "+ str(int(dur%300)) +  " -i '" + train_path[i] + "' -ar " + str(DEFAULT_FS) + " -- \"" + dst_dir + "/" + str(cur) + ".wav\""))
    cur+=1
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# 관련 라이브러리 가져오기
import matplotlib.pyplot as plt

import os
from glob import glob

base_dir = '/catclass/output1'
train_folder = glob(base_dir)
train_path = []
for folder in train_folder:
    tmp = glob(folder + '/*')
    train_path += tmp

def ctft_to_peaks(carr : np.ndarray, threshold = 1, max_peak_num = 10):
    rising = np.zeros(shape=(max_peak_num, carr.shape[1]))
    falling = np.zeros(shape=(max_peak_num , carr.shape[1]))
    diff=np.diff(np.sign(carr.T-threshold), axis = 1)

    for arr, num in [(rising, 2), (falling, -2)]:
        a,b = np.where(diff==num)
        for i in range(diff.shape[0]):
            temp=b[a==i]
            minlen = min(max_peak_num, len(temp))
            arr[:minlen,i]=temp[:minlen]

    return (rising, falling)

for vidno in range(len(train_path)):
    try:
        y, sr = librosa.load(train_path[vidno])

        S_full, phase = librosa.magphase(librosa.stft(y))



        # We'll compare frames using cosine similarity, and aggregate similar frames
        # by taking their (per-frequency) median value.
        #
        # To avoid being biased by local continuity, we constrain similar frames to be
        # separated by at least 2 seconds.
        #
        # This suppresses sparse/non-repetetitive deviations from the average spectrum,
        # and works well to discard vocal elements.

        S_filter = librosa.decompose.nn_filter(S_full,
                                            aggregate=np.median,
                                            metric='cosine',
                                            width=int(librosa.time_to_frames(2, sr=sr)))

        # The output of the filter shouldn't be greater than the input
        # if we assume signals are additive.  Taking the pointwise minimium
        # with the input spectrum forces this.
        S_filter = np.minimum(S_full, S_filter)
        # We can also use a margin to reduce bleed between the vocals and instrumentation masks.
        # Note: the margins need not be equal for foreground and background separation
        margin_i, margin_v = 2, 10
        power = 2

        mask_i = librosa.util.softmask(S_filter,
                                    margin_i * (S_full - S_filter),
                                    power=power)

        mask_v = librosa.util.softmask(S_full - S_filter,
                                    margin_v * S_filter,
                                    power=power)

        # Once we have the masks, simply multiply them with the input spectrum
        # to separate the components
        S_foreground = mask_v * S_full
        S_background = mask_i * S_full
        # sphinx_gallery_thumbnail_number = 2


        rising, falling = ctft_to_peaks(S_foreground, threshold=0.1, max_peak_num=5)

        x=np.arange(0, rising.shape[1],1/1).astype(int)


        #의미있는 부분만 잘라내기
        cnt_mat = (rising > 1e-5).sum(axis=0)
        thres = 5 - 0.5
        cutpoint_rising = np.where(np.diff(np.sign(cnt_mat-thres))==2)[0]
        cutpoint_falling = np.where(np.diff(np.sign(cnt_mat-thres))==-2)[0]+1
        if(cnt_mat[0] > thres):
            cutpoint_rising = np.insert(cutpoint_rising,0,0)

        if len(cutpoint_rising)!=len(cutpoint_falling):
            cutpoint_rising = cutpoint_rising[:-1]

        for i in range(len(cutpoint_rising)):
            if 1.3>=(librosa.frames_to_time(cutpoint_falling[i],sr=sr)-librosa.frames_to_time(cutpoint_rising[i],sr=sr))>=0.3:
                #print(cutpoint_rising[i], cutpoint_falling[i])
                print(("ffmpeg -y -ss " + str(librosa.frames_to_time(cutpoint_rising[i],sr=sr)) + " -t " + str(librosa.frames_to_time(cutpoint_falling[i],sr=sr)-librosa.frames_to_time(cutpoint_rising[i],sr=sr)) + " -i " +str(train_path[vidno])+" /catclass/dataset1/caterwaul/"+str(train_path[vidno].split('/')[-1].split(".")[0])+'_'+str(i)+".wav"))
                os.system(("ffmpeg -y -ss " + str(librosa.frames_to_time(cutpoint_rising[i],sr=sr)) + " -t " + str(librosa.frames_to_time(cutpoint_falling[i],sr=sr)-librosa.frames_to_time(cutpoint_rising[i],sr=sr)) + " -i " +str(train_path[vidno])+" /catclass/dataset1/caterwaul/"+str(train_path[vidno].split('/')[-1].split(".")[0])+'_'+str(i)+".wav"))
    except:
        print("error at "+str(vidno)+':'+str(train_path[vidno].split('/')[-1].split(".")[0]))

# %%
import pandas as pd
import numpy as np
import playsound

typ = int(input('meow : 1, caterwaul : 2'))
if typ==1:
    typ='meow'
if typ==2:
    typ='caterwaul'
df_labeled = pd.read_csv(typ+'_labeled_path_final1.csv')
# if i=1 then slice 0-1/3, 2 then 1/3-2/3, 3 then 2/3-3/3
df_labeled.columns = ['path','label']

for j in range(0,len(df_labeled)):
    if df_labeled['label'][j]==1:
        print("/".join(df_labeled['path'][j].split('/')[1:]))
        playsound.playsound("/".join(df_labeled['path'][j].split('/')[2:]))
        input()
# Out:
# catclass/dataset1/caterwaul/664_200.wav
# catclass/dataset1/caterwaul/407_243.wav
# catclass/dataset1/caterwaul/534_201.wav
# catclass/dataset1/caterwaul/516_18.wav
# catclass/dataset1/caterwaul/574_330.wav
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\lukek\Desktop\설곽\Python\catclass\main.ipynb Cell 10 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/lukek/Desktop/%EC%84%A4%EA%B3%BD/Python/catclass/main.ipynb#X12sZmlsZQ%3D%3D?line=15'>16</a> print("/".join(df_labeled['path'][j].split('/')[1:]))
#      <a href='vscode-notebook-cell:/c%3A/Users/lukek/Desktop/%EC%84%A4%EA%B3%BD/Python/catclass/main.ipynb#X12sZmlsZQ%3D%3D?line=16'>17</a> playsound.playsound("/".join(df_labeled['path'][j].split('/')[2:]))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/lukek/Desktop/%EC%84%A4%EA%B3%BD/Python/catclass/main.ipynb#X12sZmlsZQ%3D%3D?line=17'>18</a> input()
#
# ...

# %%
import shutil
df = pd.read_csv("meow_labeled_path_final.csv")
for i in range(len(df)):
    if df['label'][i]==1:
        shutil.copyfile(df['path'][i],"./full_dataset/meow/"+df['path'][i].split('\\')[-1])

# %%
import shutil
df = pd.read_csv("caterwaul_labeled_path_final1.csv")
for i in range(len(df)):
    if df['label'][i]==1:
        shutil.copyfile("/".join(df['path'][j].split('/')[2:]),"./full_dataset/caterwaul/"+df['path'][i].split('/')[-1])

# %%
import splitfolders
splitfolders.ratio('/catclass/full_dataset/', output="/catclass/full_dataset/", seed=1337, ratio=(.8, 0.1,0.1))
# Out:
# Copying files: 6686 files [00:02, 2326.49 files/s]

# %%
import torch
import torchaudio
import torchaudio.functional as F
from IPython.display import Audio

print(torch.__version__)
print(torchaudio.__version__)

import matplotlib.pyplot as plt
from torchaudio.utils import download_asset

# Load the data

waveform1, sample_rate = torchaudio.load("/catclass/full_dataset/meow/-_8E5aDUqas_30_14.wav", channels_first=False)
waveform11, sample_rate = torchaudio.load("/catclass/full_dataset/meow/-_8E5aDUqas_30_14.wav")
waveform111, sample_rate = torchaudio.load("/catclass/full_dataset/meow/-_8E5aDUqas_30_14.wav")
rir, sample_rate = torchaudio.load("/catclass/rir_16000.wav")

augmented = F.fftconvolve(waveform11, rir)

# Define effects
effect = ",".join(
    [
        "lowpass=frequency=300:poles=1",  # apply single-pole lowpass filter
        "atempo=0.9",  # reduce the speed
    ],
)


# Apply effects
def apply_effect(waveform, sample_rate, effect):
    effector = torchaudio.io.AudioEffector(effect=effect)
    return effector.apply(waveform, sample_rate)

noise, _ = torchaudio.load("/catclass/noise_16000.wav")
noise = noise[:, : waveform111.shape[1]]

noisy_speeches = F.add_noise(waveform111, noise, torch.tensor([1]))

waveform2 = apply_effect(waveform1, sample_rate, effect)

print(waveform1.shape, sample_rate)
print(waveform2.shape, sample_rate)
#Audio(augmented, rate=sample_rate)
torchaudio.save("/catclass/2.wav", waveform2.T, sample_rate)
torchaudio.save("/catclass/3.wav", augmented, sample_rate)
torchaudio.save("/catclass/4.wav", noisy_speeches, sample_rate)
# Out:
# 2.1.0+cu121
# 2.1.0+cu121
# torch.Size([11889, 2]) 16000
# torch.Size([12926, 2]) 16000

# %%
SAMPLE_NOISE = download_asset("tutorial-assets/Lab41-SRI-VOiCES-rm1-babb-mc01-stu-clo-8000hz.wav")
#speech, _ = torchaudio.load(SAMPLE_SPEECH)
noise, sample_rate = torchaudio.load(SAMPLE_NOISE)
#noise = noise[:, : speech.shape[1]]

#snr_dbs = torch.tensor([20, 10, 3])
#noisy_speeches = F.add_noise(speech, noise, snr_dbs)
torchaudio.save("/catclass/noise.wav",noise,sample_rate)
# Out:
# 100%|██████████| 78.2k/78.2k [00:00<00:00, 220kB/s]
